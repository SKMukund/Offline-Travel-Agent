# %% [markdown]
# Downloading NYC Data

# %%
# %load_ext autoreload
# %autoreload 2

from src.downloader import download_city_data

print("Input a valid Country:")
country = input()

print("Input a valid state(If you don't know or not in the USA, type in N/A):")
state = input()

print("Input a valid City:")
city = input()

download_city_data(country, city, state)
# Out:
# Input a valid Country:
# Input a valid state(If you don't know or not in the USA, type in N/A):
# Input a valid City:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[1], line 15
#      11
#      12 print("Input a valid City:")
#      13 city = input()
#      14
# ---> 15 download_city_data(country, city, state)
#      16
#
# File ~/Work/CS Projects/Offline-Travel-Agent/src/downloader.py:55, in download_city_data(country, city, base_folder, state)
#      52 if not city or not isinstance(city, str):
#      53     raise ValueError("City must be a non-empty string")
# ---> 55 folder.mkdir(parents=True, exist_ok=True)
#      56 print(f"Saving to: {folder}\n")
#      58 #Check if location has a state and build folder path
#
# UnboundLocalError: cannot access local variable 'folder' where it is not associated with a value

# %% [markdown]
# Data Loader

# %%
from src.data_loader import load_city_data


data = load_city_data("France", "Paris", "")

print(data.keys())
# Out:
# ✅ Loading restaurants...
# ✅ Loading cafes...
# ✅ Loading bars...
# Skipping field check_in: unsupported OGR type: 10
# Skipping field check_out: unsupported OGR type: 10
# ✅ Loading hotels...
# ✅ Loading attractions...
# ✅ Loading museums...
# ⏭️  Skipping subway_stations — file not found
# ⏭️  Skipping parks — file not found
# ⏭️  Skipping pharmacies — file not found
# ✅ Loading atms...
# ⏭️  Skipping hospitals — file not found
#
# Loaded 7 categories for !
# dict_keys(['restaurants', 'cafes', 'bars', 'hotels', 'attractions', 'museums', 'atms'])
