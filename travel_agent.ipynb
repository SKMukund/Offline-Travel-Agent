# %% [markdown]
# Downloading NYC Data

# %%
# %load_ext autoreload
# %autoreload 2

from src.downloader import download_city_data

print("Input a valid Country:")
country = input()

print("Input a valid state(If you don't know or not in the USA, type in N/A):")
state = input()

print("Input a valid City:")
city = input()

download_city_data(country, city, state)
# Out:
# Input a valid Country:
# Input a valid state(If you don't know or not in the USA, type in N/A):
# Input a valid City:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 15
#      11
#      12 print("Input a valid City:")
#      13 city = input()
#      14
# ---> 15 download_city_data(country, city, state)
#      16
#
# File ~/Work/CS Projects/Offline-Travel-Agent/src/downloader.py:52, in download_city_data(country, city, state)
#      50 #Throw Exceptions
#      51 if not country or not isinstance(country, str):
# ---> 52     raise ValueError("Country must be a non-empty string")
#      54 if not city or not isinstance(city, str):
#      55     raise ValueError("City must be a non-empty string")
#
# ValueError: Country must be a non-empty string

# %% [markdown]
# Data Loader

# %%
from src.data_loader import load_city_data

data = load_city_data("USA", "NYC", "New York")

agent_data = {
    "restaurants": data.get("restaurants"),
    "cafes": data.get("cafes"),
    "bars": data.get("bars"),
    "hotels": data.get("hotels"),
    "attractions": data.get("attractions"),
    "museums": data.get("museums"),
}

agent_data = {k: v for k, v in agent_data.items() if v is not None}

print("Agent has access to:", list(agent_data.keys()))

print(data.keys())
# Out:
# Loading from: data/USA/New York/NYC
# Files found: [PosixPath('data/USA/New York/NYC/hospitals.geojson'), PosixPath('data/USA/New York/NYC/subway_stations.geojson'), PosixPath('data/USA/New York/NYC/atms.geojson'), PosixPath('data/USA/New York/NYC/museums.geojson'), PosixPath('data/USA/New York/NYC/restaurants.geojson'), PosixPath('data/USA/New York/NYC/cafes.geojson'), PosixPath('data/USA/New York/NYC/pharmacies.geojson'), PosixPath('data/USA/New York/NYC/attractions.geojson'), PosixPath('data/USA/New York/NYC/hotels.geojson'), PosixPath('data/USA/New York/NYC/parks.geojson'), PosixPath('data/USA/New York/NYC/bars.geojson')]
#
# Loading restaurants...
# Loading cafes...
# Loading bars...
# Loading hotels...
# Loading attractions...
# Loading museums...
# Loading subway_stations...
# Loading parks...
# Loading pharmacies...
# Loading atms...
# Loading hospitals...
#
# Loaded 11 categories for NYC!
# Agent has access to: ['restaurants', 'cafes', 'bars', 'hotels', 'attractions', 'museums']
# dict_keys(['restaurants', 'cafes', 'bars', 'hotels', 'attractions', 'museums', 'subway_stations', 'parks', 'pharmacies', 'atms', 'hospitals'])

# %% [markdown]
# Main Agent

# %%
from src.data_loader import load_city_data
from src.agent import run_travel_agent

data = load_city_data("USA", "NYC", "New York")
run_travel_agent(data, radius=1.0, unit="km", location=("USA", "NYC", "New York"))
# Out:
# ============================================================
#   Offline Travel Agent  (powered by llama3.2 via Ollama)
# ============================================================
#
# Agent: "Hi! I'm your offline travel agent for USA, NYC, New York. I can help you find restaurants, cafes, bars, hotels, attractions, museums, parks, and more — all offline. Tell me where you are and what you're looking for. (Type 'quit' to exit, or include '2 km' / '1.5 miles' to change the search radius.)"
# User: "resturants near time square"
# Agent: "Here are some restaurants within 0.5 miles of Times Square:
#
# **American cuisine**
#
# * Carmine's (0.3 miles) - Italian-American
# * Junior's (0.4 miles) - Classic American diner
# * The Hard Rock Cafe (0.2 miles) - Burgers, sandwiches, and rock 'n' roll
#
# **Asian cuisine**
#
# * P.F. Chang's China Bistro (0.2 miles) - Chinese
# * Pei Wei Asian Diner (0.3 miles) - Pan-Asian
# * Sushi Teriyaki (0.4 miles) - Japanese
#
# **Italian cuisine**
#
# * Bubba Gump Shrimp Co. (0.3 miles) - Seafood and Italian-American
# * Carmine's has an Italian menu too
# * Caffe Milano (0.5 miles) - Italian coffeehouse"
# Agent: "Goodbye! Safe travels!"

# %%
import sys
sys.path.insert(0, "src")

from data_loader import load_city_data
from cache import SpatialCache
from filter import filter_nearby, to_km
from map_utils import generate_map, display_map_in_notebook

# 1. Load data and build spatial index
data = load_city_data("USA", "NYC", "New York")
cache = SpatialCache(data)

# 2. Query places near Midtown
midtown = (40.7549, -73.9840)
results = filter_nearby(cache, midtown, radius_km=1.0, categories=["restaurants", "cafes"])

# 3. Generate the map — returns (file:// URI, folium.Map)
path, m = generate_map(
    area="midtown",
    coords=midtown,
    results=results,
)

# 4a. In a Jupyter notebook — display inline via local HTTP server
display_map_in_notebook(m, path)

# 4b. Click to open in browser
print(f"Open in browser: {path}")
